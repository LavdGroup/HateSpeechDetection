# %%
project_path = "/content/drive/MyDrive/DNLP/hate-speech_BERT_final/"
scripts_path = project_path+"scripts"
# %cd $scripts_path
# Out:
# /content/drive/MyDrive/DNLP/hate-speech_BERT_final/scripts

# %%
# execute the preprocessing pipeline beforehand

# %%
# prerequirements
# %%bash
pip install docopt
pip install folium==0.2.1  # required for pytorch bert
pip install pytorch-pretrained-bert
# Out:
# ...
#   Created wheel for folium: filename=folium-0.2.1-py3-none-any.whl size=79808 sha256=ef56a7dc63cef916588cdb4e855e3002954f9e3b9b8a799a48643a8ad2111110
#   Stored in directory: /root/.cache/pip/wheels/9a/f0/3a/3f79a6914ff5affaf50cabad60c9f4d565283283c97f0bdccf
# Successfully built folium
# ...
#   Attempting uninstall: folium
#     Found existing installation: folium 0.8.3
#     Uninstalling folium-0.8.3:
#       Successfully uninstalled folium-0.8.3
# ...
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
# ...

# %%
#split train dev test
davidson_dir = project_path + "datasets/davidson/"
davidson_path = davidson_dir + "davidson_preprocessed.csv"

# !python3 train_dev_test_split.py $davidson_path $davidson_dir
# Out:
# running train_dev_test.py with the following argumnets:
# {'--dev': '0.1',
#  '--help': False,
#  '--random_state': '42',
#  '--test': '0.1',
#  '<data_path>': '/content/drive/MyDrive/DNLP/hate-speech_BERT_final/datasets/davidson/davidson_preprocessed.csv',
#  '<output_dir>': '/content/drive/MyDrive/DNLP/hate-speech_BERT_final/datasets/davidson/'}

# %%
# train default model
# %%bash
python3 run_bert.py train default --cuda --train="../datasets/davidson/train.csv" --dev="../datasets/davidson/val.csv"
# Out:
# running run_bert.py with the following argumnets:
# {'--batch-size': '32',
#  '--clip-grad': '1.0',
#  '--cuda': True,
#  '--dev': '../datasets/davidson/val.csv',
#  '--dropout': '0.1',
#  '--help': False,
#  '--lr': '0.001',
#  '--lr-bert': '0.00002',
#  '--lr-decay': '0.5',
#  '--max-epoch': '3',
#  '--max-num-trial': '3',
#  '--out-channel': '16',
#  '--patience': '3',
#  '--seed': '42',
#  '--test': 'test.csv',
#  '--train': '../datasets/davidson/train.csv',
#  '--valid-niter': '500',
#  '--verbose': False,
#  'MODEL': 'default',
#  'test': False,
#  'train': True}
#
# prefix:  default
# --------------------------------------------------------------------------------
# Training:
# Validation
# Validation
# reached maximum number of epochs!
# Training time: 309.97521686553955
# ...

# %%
# test default model
# %%bash
python3 run_bert.py test default --cuda --test="../datasets/davidson/test.csv" --verbose
# Out:
# running run_bert.py with the following argumnets:
# {'--batch-size': '32',
#  '--clip-grad': '1.0',
#  '--cuda': True,
#  '--dev': 'val.csv',
#  '--dropout': '0.1',
#  '--help': False,
#  '--lr': '0.001',
#  '--lr-bert': '0.00002',
#  '--lr-decay': '0.5',
#  '--max-epoch': '3',
#  '--max-num-trial': '3',
#  '--out-channel': '16',
#  '--patience': '3',
#  '--seed': '42',
#  '--test': '../datasets/davidson/test.csv',
#  '--train': 'train.csv',
#  '--valid-niter': '500',
#  '--verbose': True,
#  'MODEL': 'default',
#  'test': True,
#  'train': False}
#
# load best model...
# loss: 0.54
# weighted F1 0.8520547132948068
# --------------------------------------------------------------------------------
# precision score for offensive: 0.97
# recall score for offensive: 0.80
# f1 score for offensive: 0.88
# --------------------------------------------------------------------------------
# precision score for neither: 0.86
# recall score for neither: 0.92
# f1 score for neither: 0.89
# ...

# %%
# train nonlinear model
# %%bash
python3 run_bert.py train nonlinear --cuda --train="../datasets/davidson/train.csv" --dev="../datasets/davidson/val.csv"
# Out:
# running run_bert.py with the following argumnets:
# {'--batch-size': '32',
#  '--clip-grad': '1.0',
#  '--cuda': True,
#  '--dev': '../datasets/davidson/val.csv',
#  '--dropout': '0.1',
#  '--help': False,
#  '--lr': '0.001',
#  '--lr-bert': '0.00002',
#  '--lr-decay': '0.5',
#  '--max-epoch': '3',
#  '--max-num-trial': '3',
#  '--out-channel': '16',
#  '--patience': '3',
#  '--seed': '42',
#  '--test': 'test.csv',
#  '--train': '../datasets/davidson/train.csv',
#  '--valid-niter': '500',
#  '--verbose': False,
#  'MODEL': 'nonlinear',
#  'test': False,
#  'train': True}
#
# prefix:  nonlinear
# --------------------------------------------------------------------------------
# Training:
# Validation
# Validation
# reached maximum number of epochs!
# Training time: 319.0038311481476
# ...

# %%
# test nonlinear model
# %%bash
python3 run_bert.py test nonlinear --cuda --test="../datasets/davidson/test.csv" --verbose
# Out:
# running run_bert.py with the following argumnets:
# {'--batch-size': '32',
#  '--clip-grad': '1.0',
#  '--cuda': True,
#  '--dev': 'val.csv',
#  '--dropout': '0.1',
#  '--help': False,
#  '--lr': '0.001',
#  '--lr-bert': '0.00002',
#  '--lr-decay': '0.5',
#  '--max-epoch': '3',
#  '--max-num-trial': '3',
#  '--out-channel': '16',
#  '--patience': '3',
#  '--seed': '42',
#  '--test': '../datasets/davidson/test.csv',
#  '--train': 'train.csv',
#  '--valid-niter': '500',
#  '--verbose': True,
#  'MODEL': 'nonlinear',
#  'test': True,
#  'train': False}
#
# load best model...
# loss: 0.67
# weighted F1 0.861684412906307
# --------------------------------------------------------------------------------
# precision score for offensive: 0.97
# recall score for offensive: 0.86
# f1 score for offensive: 0.91
# --------------------------------------------------------------------------------
# precision score for neither: 0.76
# recall score for neither: 0.94
# f1 score for neither: 0.84
# ...

# %%
# train lstm model
# %%bash
python3 run_bert.py train lstm --cuda --train="../datasets/davidson/train.csv" --dev="../datasets/davidson/val.csv"
# Out:
# running run_bert.py with the following argumnets:
# {'--batch-size': '32',
#  '--clip-grad': '1.0',
#  '--cuda': True,
#  '--dev': '../datasets/davidson/val.csv',
#  '--dropout': '0.1',
#  '--help': False,
#  '--lr': '0.001',
#  '--lr-bert': '0.00002',
#  '--lr-decay': '0.5',
#  '--max-epoch': '3',
#  '--max-num-trial': '3',
#  '--out-channel': '16',
#  '--patience': '3',
#  '--seed': '42',
#  '--test': 'test.csv',
#  '--train': '../datasets/davidson/train.csv',
#  '--valid-niter': '500',
#  '--verbose': False,
#  'MODEL': 'lstm',
#  'test': False,
#  'train': True}
#
# prefix:  lstm
# Traceback (most recent call last):
#   File "run_bert.py", line 327, in <module>
#     train(args)
#   File "run_bert.py", line 92, in train
#     train_label_weight = torch.tensor([label_max/train_label[i] for i in range(len(train_label))], device=device)  # give more weight to underrepresented classes
#   File "/usr/local/lib/python3.7/dist-packages/torch/cuda/__init__.py", line 214, in _lazy_init
# ...

# %%
# test lstm model
# %%bash
python3 run_bert.py test lstm --cuda --test="../datasets/davidson/test.csv" --verbose
# Out:
# running run_bert.py with the following argumnets:
# {'--batch-size': '32',
#  '--clip-grad': '1.0',
#  '--cuda': True,
#  '--dev': 'val.csv',
#  '--dropout': '0.1',
#  '--help': False,
#  '--lr': '0.001',
#  '--lr-bert': '0.00002',
#  '--lr-decay': '0.5',
#  '--max-epoch': '3',
#  '--max-num-trial': '3',
#  '--out-channel': '16',
#  '--patience': '3',
#  '--seed': '42',
#  '--test': '../datasets/davidson/test.csv',
#  '--train': 'train.csv',
#  '--valid-niter': '500',
#  '--verbose': True,
#  'MODEL': 'lstm',
#  'test': True,
#  'train': False}
#
# load best model...
# loss: 1.09
# weighted F1 0.6707606009262397
# --------------------------------------------------------------------------------
# precision score for offensive: 0.77
# recall score for offensive: 1.00
# f1 score for offensive: 0.87
# --------------------------------------------------------------------------------
# precision score for neither: 0.00
# recall score for neither: 0.00
# f1 score for neither: 0.00
# ...

# %%
# train cnn model
# %%bash
python3 run_bert.py train cnn --cuda --train="../datasets/davidson/train.csv" --dev="../datasets/davidson/val.csv"
# Out:
# running run_bert.py with the following argumnets:
# {'--batch-size': '32',
#  '--clip-grad': '1.0',
#  '--cuda': True,
#  '--dev': '../datasets/davidson/val.csv',
#  '--dropout': '0.1',
#  '--help': False,
#  '--lr': '0.001',
#  '--lr-bert': '0.00002',
#  '--lr-decay': '0.5',
#  '--max-epoch': '3',
#  '--max-num-trial': '3',
#  '--out-channel': '16',
#  '--patience': '3',
#  '--seed': '42',
#  '--test': 'test.csv',
#  '--train': '../datasets/davidson/train.csv',
#  '--valid-niter': '500',
#  '--verbose': False,
#  'MODEL': 'cnn',
#  'test': False,
#  'train': True}
#
# prefix:  cnn
# --------------------------------------------------------------------------------
# Training:
# Validation
# Validation
# reached maximum number of epochs!
# Training time: 1318.1506781578064
# ...

# %%
# test cnn model
# %%bash
python3 run_bert.py test cnn --cuda --test="../datasets/davidson/test.csv" --verbose
# Out:
# running run_bert.py with the following argumnets:
# {'--batch-size': '32',
#  '--clip-grad': '1.0',
#  '--cuda': True,
#  '--dev': 'val.csv',
#  '--dropout': '0.1',
#  '--help': False,
#  '--lr': '0.001',
#  '--lr-bert': '0.00002',
#  '--lr-decay': '0.5',
#  '--max-epoch': '3',
#  '--max-num-trial': '3',
#  '--out-channel': '16',
#  '--patience': '3',
#  '--seed': '42',
#  '--test': '../datasets/davidson/test.csv',
#  '--train': 'train.csv',
#  '--valid-niter': '500',
#  '--verbose': True,
#  'MODEL': 'cnn',
#  'test': True,
#  'train': False}
#
# load best model...
# loss: 0.55
# weighted F1 0.8887216581931512
# --------------------------------------------------------------------------------
# precision score for offensive: 0.97
# recall score for offensive: 0.88
# f1 score for offensive: 0.92
# --------------------------------------------------------------------------------
# precision score for neither: 0.84
# recall score for neither: 0.92
# f1 score for neither: 0.88
# ...
